# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv('encodeddata.csv')

# %%
dt
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
dt['Make'].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
dt['Make'].nunique()
# Out:
# 48

# %%
dt[['Make','Make_encode']]
# Out:
#           Make  Make_encode
# 0          BMW            4
# 1          BMW            4
# 2          BMW            4
# 3          BMW            4
# 4          BMW            4
# ...        ...          ...
# 11909    Acura            0
# 11910    Acura            0
# 11911    Acura            0
# 11912    Acura            0
# 11913  Lincoln           25
#
# [11914 rows x 2 columns]

# %%
make_encode=dt[['Make','Make_encode']].drop_duplicates()

# %%
make_encode
# Out:
#                 Make  Make_encode
# 0                BMW            4
# 17              Audi            3
# 32              FIAT           12
# 35     Mercedes-Benz           31
# 64          Chrysler           10
# 87            Nissan           33
# 104            Volvo           47
# 112            Mazda           29
# 194       Mitsubishi           32
# 294          Ferrari           13
# 474       Alfa Romeo            1
# 479           Toyota           45
# 604          McLaren           30
# 611          Maybach           28
# 674          Pontiac           36
# 736          Porsche           37
# 800             Saab           39
# 1137             GMC           15
# 1171         Hyundai           19
# 1189        Plymouth           35
# 1192           Honda           18
# 1287      Oldsmobile           34
# 1300          Suzuki           43
# 1331            Ford           14
# 1367        Cadillac            8
# 1426             Kia           21
# ...

# %%
dt[['Model','Model_encode']]
# Out:
#             Model  Model_encode
# 0      1 Series M             1
# 1        1 Series             0
# 2        1 Series             0
# 3        1 Series             0
# 4        1 Series             0
# ...           ...           ...
# 11909         ZDX           901
# 11910         ZDX           901
# 11911         ZDX           901
# 11912         ZDX           901
# 11913      Zephyr           902
#
# [11914 rows x 2 columns]

# %%
model_encode=dt[['Model','Model_encode']].drop_duplicates()

# %%
model_encode
# Out:
#             Model  Model_encode
# 0      1 Series M             1
# 1        1 Series             0
# 17            100             2
# 32     124 Spider             3
# 35      190-Class             4
# ...           ...           ...
# 11890        Z4 M           899
# 11894          Z4           898
# 11903          Z8           900
# 11906         ZDX           901
# 11913      Zephyr           902
#
# [915 rows x 2 columns]

# %%
dt[['Engine Fuel Type','Engine Fuel Type_encode']]
# Out:
#                      Engine Fuel Type  Engine Fuel Type_encode
# 0         premium unleaded (required)                        8
# 1         premium unleaded (required)                        8
# 2         premium unleaded (required)                        8
# 3         premium unleaded (required)                        8
# 4         premium unleaded (required)                        8
# ...                               ...                      ...
# 11909     premium unleaded (required)                        8
# 11910     premium unleaded (required)                        8
# 11911     premium unleaded (required)                        8
# 11912  premium unleaded (recommended)                        7
# 11913                regular unleaded                        9
#
# [11914 rows x 2 columns]

# %%
enginefuletype_encode=dt[['Engine Fuel Type','Engine Fuel Type_encode']].drop_duplicates()

# %%
enginefuletype_encode
# Out:
#                                   Engine Fuel Type  Engine Fuel Type_encode
# 0                      premium unleaded (required)                        8
# 17                                regular unleaded                        9
# 32                  premium unleaded (recommended)                        7
# 64                        flex-fuel (unleaded/E85)                        4
# 135                                         diesel                        0
# 539                                       electric                        1
# 804   flex-fuel (premium unleaded recommended/E85)                        2
# 2556                                   natural gas                        6
# 2850     flex-fuel (premium unleaded required/E85)                        3
# 5825              flex-fuel (unleaded/natural gas)                        5

# %%
dt[['Transmission Type','Transmission Type_encode']]
# Out:
#       Transmission Type  Transmission Type_encode
# 0                MANUAL                         3
# 1                MANUAL                         3
# 2                MANUAL                         3
# 3                MANUAL                         3
# 4                MANUAL                         3
# ...                 ...                       ...
# 11909         AUTOMATIC                         1
# 11910         AUTOMATIC                         1
# 11911         AUTOMATIC                         1
# 11912         AUTOMATIC                         1
# 11913         AUTOMATIC                         1
#
# [11914 rows x 2 columns]

# %%
transmissiontype_encode=dt[['Transmission Type','Transmission Type_encode']].drop_duplicates()

# %%
transmissiontype_encode
# Out:
#      Transmission Type  Transmission Type_encode
# 0               MANUAL                         3
# 19           AUTOMATIC                         1
# 296   AUTOMATED_MANUAL                         0
# 539       DIRECT_DRIVE                         2
# 1289           UNKNOWN                         4

# %%
dw_encode=dt[['Driven_Wheels','Driven_Wheels_encode',]].drop_duplicates()

# %%
vs_encode=dt[['Vehicle Style','Vehicle Style_encode',]].drop_duplicates()

# %%
vsz_encode=dt[['Vehicle Size','Vehicle Size_encode',]].drop_duplicates()

# %%
data=pd.read_json('new.json')

# %%
data
# Out:
#                 Make  Make_encode                Engine Fuel Type  \
# 0                BMW          4.0     premium unleaded (required)
# 17              Audi          3.0                regular unleaded
# 32              FIAT         12.0  premium unleaded (recommended)
# 35     Mercedes-Benz         31.0                             NaN
# 64          Chrysler         10.0        flex-fuel (unleaded/E85)
# ...              ...          ...                             ...
# 11913            NaN          NaN                             NaN
# 296              NaN          NaN                             NaN
# 1289             NaN          NaN                             NaN
# 1684             NaN          NaN                             NaN
# 3553             NaN          NaN                             NaN
#
#        Engine Fuel Type_encode      Driven_Wheels  Driven_Wheels_encode  \
# 0                          8.0   rear wheel drive                   3.0
# ...
